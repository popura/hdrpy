# %%
import hdrpy
import matplotlib.pyplot as plt
import numpy as np

# %%
hdr = hdrpy.io.read("../data/memorial_o876.hdr")

# %%
f = hdrpy.tmo.ReinhardTMO()
ldr = f(hdr)
plt.imshow(ldr)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
lum = hdrpy.get_luminance(hdr)
lum.shape
# Out:
# (768, 512)

# %%
plt.hist(np.log(lum).reshape(-1, 1), bins=256)
plt.show()
